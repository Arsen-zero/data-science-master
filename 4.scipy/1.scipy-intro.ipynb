# %%
import numpy as np
import pylab as pl

# %%
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']

# %% [markdown]
# # SciPy-数值计算库

# %%
import scipy
scipy.__version__
# Out:
# '1.3.1'

# %% [markdown]
# ## 常数和特殊函数

# %%
from scipy import constants as C
print (C.c) # 真空中的光速
print (C.h) # 普朗克常数
# Out:
# 299792458.0
# 6.62607004e-34

# %%
C.physical_constants["electron mass"]
# Out:
# (9.10938356e-31, 'kg', 1.1e-38)

# %%
# 1英里等于多少米, 1英寸等于多少米, 1克等于多少千克, 1磅等于多少千克
print(C.mile)
print(C.inch)
print(C.gram)
print(C.pound)
# Out:
# 1609.3439999999998
# 0.0254
# 0.001
# 0.45359236999999997

# %%
import scipy.special as S

# %%
print (1 + 1e-20)
print (np.log(1+1e-20))
print (S.log1p(1e-20))
# Out:
# 1.0
# 0.0
# 1e-20

# %%
m = np.linspace(0.1, 0.9, 4)
u = np.linspace(-10, 10, 200)
results = S.ellipj(u[:, None], m[None, :])

print([y.shape for y in results])
# Out:
# [(200, 4), (200, 4), (200, 4), (200, 4)]

# %%
#%figonly=使用广播计算得到的`ellipj()`返回值
fig, axes = pl.subplots(2, 2, figsize=(12, 4))
labels = ["$sn$", "$cn$", "$dn$", "$\phi$"]
for ax, y, label in zip(axes.ravel(), results, labels):
    ax.plot(u, y)
    ax.set_ylabel(label)
    ax.margins(0, 0.1)
    
axes[1, 1].legend(["$m={:g}$".format(m_) for m_ in m], loc="best", ncol=2);
# Out:
# d:\app\python3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# d:\app\python3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
